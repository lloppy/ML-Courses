# %%
import pandas as pd
import numpy as np

file_url = "https://drive.google.com/uc?id=1XVXE8O-nYgSmrghaweMeLnAMGq57VoJt"

# data frame
df = pd.read_csv(file_url)
df.head()

playstore = df
playstore_copy = df

# %% [markdown]
# # task 1
# Сохраните в переменные data_head и data_tail первые и последние 3 строки из датафрейма соответственно. Датафрейм уже находится в переменной playstore.

# %%
data_head = playstore[0:3]
data_tail  = playstore[len(playstore): len(playstore)- 4: -1]

data_head
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#          Category  Rating  Reviews  Size    Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159   19M     10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967   14M    500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510  8.7M  5,000,000+  Free     0
#
#   Content Rating                     Genres      Last Updated Current Ver  \
# 0       Everyone               Art & Design   January 7, 2018       1.0.0
# 1       Everyone  Art & Design;Pretend Play  January 15, 2018       2.0.0
# 2       Everyone               Art & Design    August 1, 2018       1.2.4
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up

# %% [markdown]
# # task 2
# Сохраните в переменные n_col и n_row количество столбцов и строк в датафрейме соответственно. Датафрейм уже находится в переменной playstore.

# %%
n_col = playstore.shape[0]

n_row = playstore.shape[1]
n_row
# Out:
# 14

# %% [markdown]
# # task 3
# Давайте теперь посмотрим, какое количество уникальных приложений есть в наших данных (колонка App).
# В качестве ответа введите полученное число.

# %%
playstore['App'].nunique()
# Out:
# 9659

# %% [markdown]
# # task 4
# Давайте посчитаем число пропущенных значений в колонке с рейтингом приложений. Сохраните в переменную rating_missing количество пропущенных значений в колонке Rating.
# Датафрейм уже находится в переменной playstore.

# %%
rating_missing = playstore['Rating'].isna().sum()
rating_missing
# Out:
# 1474

# %% [markdown]
# # task 5
# Научимся объединять датафреймы и познакомимся с функцией concat.
# Допустим, мы хотим собрать датафрейм, который будет включать в себя: первые три строки исходного датафрейма, строки 6-8 (включительно), строки 16-19 (включительно) и колонки: App, Size, Genres, Current Ver в соответствующем порядке.
# По сути, это будет выглядеть как объединение трех, состоящих из нескольких строк, датафреймов, являющимися срезами из исходных данных.
# В качестве ответа загрузите полученный датафрейм в формате csv. При сохранении финального датафрейма, колонка с индексами должна остаться.
# NB! Помните про индексацию с нуля и правила включения/невключения границ при слайсинге

# %%
playstore_1 = playstore[['App', 'Size', 'Genres', 'Current Ver']]

first = playstore_1[0:3]
sixth = playstore_1[5:8]
sixteen = playstore_1[15:19]

concatenate_playstore = pd.concat([first, sixth, sixteen])
concatenate_playstore

concatenate_playstore.to_csv('filter_playstore.csv')

# %%
pd.read_csv('filter_playstore.csv')
# Out:
#    Unnamed: 0                                                App  Size  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook   19M
# 1           1                                Coloring book moana   14M
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...  8.7M
# 3           5                         Paper flowers instructions  5.6M
# 4           6            Smoke Effect Photo Maker - Smoke Editor   19M
# 5           7                                   Infinite Painter   29M
# 6          15                    Learn To Draw Kawaii Characters  2.7M
# 7          16       Photo Designer - Write your name with shapes  5.5M
# 8          17                           350 Diy Room Decor Ideas   17M
# 9          18                      FlipaClip - Cartoon animation   39M
#
#                       Genres Current Ver
# 0               Art & Design       1.0.0
# 1  Art & Design;Pretend Play       2.0.0
# 2               Art & Design       1.2.4
# 3               Art & Design         1.0
# 4               Art & Design         1.1
# 5               Art & Design    6.1.61.1
# 6               Art & Design         NaN
# 7               Art & Design         3.1
# 8               Art & Design         1.0
# 9               Art & Design       2.2.5

# %% [markdown]
# # task 6
#
# Для дальнейшего анализа нам необходимо убрать дубликаты приложений (колонка App) и сбросить индекс. Сохраните полученный результат в виде датафрейма в переменную unique_playstore. Датафрейм уже находится в переменной playstore.

# %%
# основное различие заключается в том, что первый подход сохраняет связанные
# с уникальными значениями строки целиком, в то время как во втором подходе
# возвращается только массив уникальных значений из столбца 'App'
# без сохранения другой информации из DataFrame

unique_playstore = playstore.drop_duplicates(subset=['App'])
# unique_playstore = playstore['App'].unique()

unique_playstore.reset_index(drop=True)
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9654       10835                                   Sya9a Maroc - FR
# 9655       10836                   Fr. Mike Schmitz Audio Teachings
# 9656       10837                             Parkinson Exercices FR
# 9657       10838                      The SCP Foundation DB fr nn5n
# 9658       10839      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews                Size     Installs  \
# 0          ART_AND_DESIGN     4.1      159                 19M      10,000+
# 1          ART_AND_DESIGN     3.9      967                 14M     500,000+
# 2          ART_AND_DESIGN     4.7    87510                8.7M   5,000,000+
# 3          ART_AND_DESIGN     4.5   215644                 25M  50,000,000+
# 4          ART_AND_DESIGN     4.3      967                2.8M     100,000+
# ...                   ...     ...      ...                 ...          ...
# 9654               FAMILY     4.5       38                 53M       5,000+
# 9655               FAMILY     5.0        4                3.6M         100+
# 9656              MEDICAL     NaN        3                9.5M       1,000+
# 9657  BOOKS_AND_REFERENCE     4.5      114  Varies with device       1,000+
# 9658            LIFESTYLE     4.5   398307                 19M  10,000,000+
#
#       Type Price Content Rating                     Genres      Last Updated  \
# 0     Free     0       Everyone               Art & Design   January 7, 2018
# 1     Free     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     Free     0       Everyone               Art & Design    August 1, 2018
# 3     Free     0           Teen               Art & Design      June 8, 2018
# 4     Free     0       Everyone    Art & Design;Creativity     June 20, 2018
# ...    ...   ...            ...                        ...               ...
# 9654  Free     0       Everyone                  Education     July 25, 2017
# 9655  Free     0       Everyone                  Education      July 6, 2018
# 9656  Free     0       Everyone                    Medical  January 20, 2017
# 9657  Free     0     Mature 17+          Books & Reference  January 19, 2015
# 9658  Free     0       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9654                1.48          4.1 and up
# 9655                 1.0          4.1 and up
# 9656                 1.0          2.2 and up
# 9657  Varies with device  Varies with device
# 9658  Varies with device  Varies with device
#
# [9659 rows x 14 columns]

# %% [markdown]
# # task 7
# В этом задании названия колонок необходимо привести к стандартному виду — все буквы должны быть нижнего регистра, а пробелы должны быть заменены на нижние подчеркивания.
# Методы, которые могут пригодиться:
#
# rename
# str.lower
# str.replace
# columns

# %%
playstore.columns = [row.replace(' ', '_').lower() for row in playstore.columns]
playstore
# Out:
#        unnamed:_0                                                app  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10835                                   Sya9a Maroc - FR
# 10836       10836                   Fr. Mike Schmitz Audio Teachings
# 10837       10837                             Parkinson Exercices FR
# 10838       10838                      The SCP Foundation DB fr nn5n
# 10839       10839      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   category  rating  reviews                size     installs  \
# 0           ART_AND_DESIGN     4.1      159                 19M      10,000+
# 1           ART_AND_DESIGN     3.9      967                 14M     500,000+
# 2           ART_AND_DESIGN     4.7    87510                8.7M   5,000,000+
# 3           ART_AND_DESIGN     4.5   215644                 25M  50,000,000+
# 4           ART_AND_DESIGN     4.3      967                2.8M     100,000+
# ...                    ...     ...      ...                 ...          ...
# 10835               FAMILY     4.5       38                 53M       5,000+
# 10836               FAMILY     5.0        4                3.6M         100+
# 10837              MEDICAL     NaN        3                9.5M       1,000+
# 10838  BOOKS_AND_REFERENCE     4.5      114  Varies with device       1,000+
# 10839            LIFESTYLE     4.5   398307                 19M  10,000,000+
#
#        type price content_rating                     genres      last_updated  \
# 0      Free     0       Everyone               Art & Design   January 7, 2018
# 1      Free     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2      Free     0       Everyone               Art & Design    August 1, 2018
# 3      Free     0           Teen               Art & Design      June 8, 2018
# 4      Free     0       Everyone    Art & Design;Creativity     June 20, 2018
# ...     ...   ...            ...                        ...               ...
# 10835  Free     0       Everyone                  Education     July 25, 2017
# 10836  Free     0       Everyone                  Education      July 6, 2018
# 10837  Free     0       Everyone                    Medical  January 20, 2017
# 10838  Free     0     Mature 17+          Books & Reference  January 19, 2015
# 10839  Free     0       Everyone                  Lifestyle     July 25, 2018
#
#               current_ver         android_ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10835                1.48          4.1 and up
# 10836                 1.0          4.1 and up
# 10837                 1.0          2.2 and up
# 10838  Varies with device  Varies with device
# 10839  Varies with device  Varies with device
#
# [10840 rows x 14 columns]

# %% [markdown]
# # task 8
# Давайте посмотрим на долю платных и бесплатных приложений. В качестве ответа введите долю бесплатных приложений. Ответ округлите до сотых, в качестве десятичного разделителя используйте точку.
# NB! Не забудьте убрать дубликаты перед подсчетом доли!

# %%
unique_playstore = playstore_copy.drop_duplicates(subset=['App'])

free = (unique_playstore['Type'] == 'Free').value_counts(normalize=True)
free
# Out:
# True     0.921627
# False    0.078373
# Name: Type, dtype: float64

# %% [markdown]
# # task 9
# Отберите из датафрейма только те приложения, которые относятся к образовательной категории  (EDUCATION) и с количеством отзывов пользователей более 1000. Сохраните новый датафрейм в переменную education_playstore.
# Данные очищены от дубликатов, названия колонок преобразованы согласно предыдущим заданиям и сохранены в датафрейме playstore.
# NB! Не забудьте сбросить индекс в полученном датафрейме!

# %%
edu_temp = df.copy()

edu_temp = edu_temp.drop_duplicates(subset=['App'])
edu_temp.reset_index(drop=True)

edu=edu_temp
edu.columns = [row.replace(' ', '_').lower() for row in edu.columns]

education_playstore = edu[(edu['genres'] == 'Education') & (edu['reviews'] > 1000)].reset_index(drop=True)
education_playstore
# Out:
#      unnamed:_0                                                app   category  \
# 0           700                                                TED  EDUCATION
# 1           701  English Communication - Learn English for Chin...  EDUCATION
# 2           702                                       Khan Academy  EDUCATION
# 3           703                         Learn English with Wlingua  EDUCATION
# 4           706                            Learn Spanish - Español  EDUCATION
# ..          ...                                                ...        ...
# 131        9822  School scientific calculator fx 500 es plus 50...     FAMILY
# 132        9838                              Google Arts & Culture     FAMILY
# 133        9848                      Learn Italian with MosaLingua     FAMILY
# 134        9973                          German Vocabulary Trainer     FAMILY
# 135       10380                                       POLARIS 2MFG     FAMILY
#
#      rating  reviews                size     installs  type  price  \
# 0       4.6   181893                 18M  10,000,000+  Free      0
# 1       4.7     2544                 18M     100,000+  Free      0
# 2       4.6    85375                 21M   5,000,000+  Free      0
# 3       4.7   314299                3.3M  10,000,000+  Free      0
# 4       4.7    32346                3.2M   1,000,000+  Free      0
# ..      ...      ...                 ...          ...   ...    ...
# 131     4.6     1553                9.2M     100,000+  Free      0
# 132     3.7    24137  Varies with device   5,000,000+  Free      0
# 133     4.7     1719  Varies with device      50,000+  Paid  $4.99
# 134     3.3     1218                1.0M     100,000+  Free      0
# 135     4.8     1228                 29M      10,000+  Free      0
#
#     content_rating     genres       last_updated  \
# 0     Everyone 10+  Education      July 27, 2018
# 1         Everyone  Education  December 29, 2017
# 2         Everyone  Education      July 27, 2018
# 3         Everyone  Education        May 2, 2018
# 4         Everyone  Education  December 18, 2017
# ..             ...        ...                ...
# 131       Everyone  Education     August 2, 2018
# 132       Everyone  Education      June 25, 2018
# 133           Teen  Education       May 31, 2018
# 134       Everyone  Education    August 24, 2012
# 135       Everyone  Education     March 28, 2018
#
#                            current_ver         android_ver
# 0                                3.2.5          4.1 and up
# 1                                  3.1          4.0 and up
# 2                                5.0.0          4.1 and up
# 3                               1.94.9          4.0 and up
# 4                                1.3.8          4.0 and up
# ..                                 ...                 ...
# 131  3.3.1-build-02-08-2018-19-release          4.0 and up
# 132                 Varies with device  Varies with device
# 133                 Varies with device  Varies with device
# 134                                1.0          2.1 and up
# 135                                1.7          4.1 and up
#
# [136 rows x 14 columns]

# %% [markdown]
# # task 10
#
# Давайте уберем лишние символы из колонки с ценой (price), чтобы далее с ней было удобнее работать, и переведем данные в тип float. Данные уже сохранены в playstore.

# %%
edu_temp['price'] = edu_temp['price'].replace('$', '').astype(float)
edu_temp['price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])
