# %% [markdown]
# # Pandas

# %%
import pandas as pd
file_url = "https://drive.google.com/uc?id=1qHst5w8frzO5GUu328CWeP1pF-noN9iz"

# data frame
df = pd.read_csv(file_url)
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.columns[1:5]
# Out:
# Index(['season', 'holiday', 'workingday', 'weather'], dtype='object')

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
import pandas as pd
file_url = "https://drive.google.com/uc?id=1qHst5w8frzO5GUu328CWeP1pF-noN9iz"

# data frame
df = pd.read_csv(file_url, dtype={'season': int})
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 2

# %%
df[df['workingday'] == 0]
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10809  2012-12-16 19:00:00       4        0           0        1  14.76
# 10810  2012-12-16 20:00:00       4        0           0        2  15.58
# 10811  2012-12-16 21:00:00       4        0           0        2  14.76
# 10812  2012-12-16 22:00:00       4        0           0        2  16.40
# 10813  2012-12-16 23:00:00       4        0           0        2  14.76
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df[
    (df['workingday'] == 0) & (df['season'] == 1)
]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 6756  2012-03-18 19:00:00       1        0           0        1  22.96
# 6757  2012-03-18 20:00:00       1        0           0        1  21.32
# 6758  2012-03-18 21:00:00       1        0           0        1  21.32
# 6759  2012-03-18 22:00:00       1        0           0        1  20.50
# 6760  2012-03-18 23:00:00       1        0           0        1  19.68
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # функции - фильтры

# %%
# df[df['windspeed'] is None]   not available
df[df['windspeed'].isna()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count]
# Index: []

# %%
df.isna()
# Out:
#        datetime  season  holiday  workingday  weather   temp  atemp  humidity  \
# 0         False   False    False       False    False  False  False     False
# 1         False   False    False       False    False  False  False     False
# 2         False   False    False       False    False  False  False     False
# 3         False   False    False       False    False  False  False     False
# 4         False   False    False       False    False  False  False     False
# ...         ...     ...      ...         ...      ...    ...    ...       ...
# 10881     False   False    False       False    False  False  False     False
# 10882     False   False    False       False    False  False  False     False
# 10883     False   False    False       False    False  False  False     False
# 10884     False   False    False       False    False  False  False     False
# 10885     False   False    False       False    False  False  False     False
#
# ...

# %%
df['workingday'].isna().any()
# Out:
# False

# %%
df[df['season'].isin([1, 3, 4])]
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # series and indexes

# %%
df['season'] == 1
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10881    False
# 10882    False
# 10883    False
# 10884    False
# 10885    False
# Name: season, Length: 10886, dtype: bool

# %%
df.loc[4] # this is 4 item; loc-lockate
# Out:
# datetime      2011-01-01 04:00:00
# season                          1
# holiday                         0
# workingday                      0
# weather                         1
# temp                         9.84
# atemp                      14.395
# humidity                       75
# windspeed                     0.0
# casual                          0
# registered                      1
# count                           1
# Name: 4, dtype: object

# %%
df.loc[4]['temp']
# Out:
# 9.84

# %%
df_dt = df.copy().set_index('datetime')
df_dt.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 04:00:00        75        0.0       0           1      1

# %%
df_dt.loc['2011-01-01 00:00:00']
# Out:
# season         1.000
# holiday        0.000
# workingday     0.000
# weather        1.000
# temp           9.840
# atemp         14.395
# humidity      81.000
# windspeed      0.000
# casual         3.000
# registered    13.000
# count         16.000
# Name: 2011-01-01 00:00:00, dtype: float64

# %%
df_dt.iloc[4]
# Out:
# season         1.000
# holiday        0.000
# workingday     0.000
# weather        1.000
# temp           9.840
# atemp         14.395
# humidity      75.000
# windspeed      0.000
# casual         0.000
# registered     1.000
# count          1.000
# Name: 2011-01-01 04:00:00, dtype: float64

# %%
df_dt.loc['2011-01-01 00:00:00', 'atemp']
# Out:
# 14.395

# %%
df_dt.iloc[3:1:-1]
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 02:00:00        80        0.0       5          27     32

# %%
df_dt.reset_index() # это копия df_dt!!
df_dt.reset_index(inplace=True) # это сам df_dt!!
df_dt
# Out:
#        index             datetime  season  holiday  workingday  weather  \
# 0          0  2011-01-01 00:00:00       1        0           0        1
# 1          1  2011-01-01 01:00:00       1        0           0        1
# 2          2  2011-01-01 02:00:00       1        0           0        1
# 3          3  2011-01-01 03:00:00       1        0           0        1
# 4          4  2011-01-01 04:00:00       1        0           0        1
# ...      ...                  ...     ...      ...         ...      ...
# 10881  10881  2012-12-19 19:00:00       4        0           1        1
# 10882  10882  2012-12-19 20:00:00       4        0           1        1
# 10883  10883  2012-12-19 21:00:00       4        0           1        1
# 10884  10884  2012-12-19 22:00:00       4        0           1        1
# 10885  10885  2012-12-19 23:00:00       4        0           1        1
#
#         temp   atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # группировка и агрегация

# %%
df.groupby('season', as_index=False).agg({'temp': 'mean'})

df.groupby('season').agg({'temp': 'mean'}).reset_index()
# Out:
#    season       temp
# 0       1  12.530491
# 1       2  22.823483
# 2       3  28.789111
# 3       4  16.649239

# %%
df.groupby(['season', 'workingday']).mean()
# Out:
# <ipython-input-47-3f6f570716ee>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['season', 'workingday']).mean()
#                     holiday   weather       temp      atemp   humidity  \
# season workingday
# 1      0           0.082751  1.446387  12.344918  14.907646  56.988345
#        1           0.000000  1.414114  12.617593  15.379768  55.973742
# 2      0           0.057143  1.388095  22.742310  26.536792  61.114286
#        1           0.000000  1.438457  22.859503  26.696046  60.736926
# 3      0           0.108108  1.369369  28.675068  32.735743  65.875000
#        1           0.000000  1.365312  28.844000  32.446949  63.280759
# 4      0           0.108108  1.346847  15.696351  19.106227  64.557432
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.groupby(['season', 'workingday'])
