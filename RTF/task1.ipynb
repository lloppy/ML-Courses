ified-id="Упражнение-45-1.46"><span class="toc-item-num">1.46&nbsp;&nbsp;</span>Упражнение 45</a></span></li><li><span><a href="#Упражнение-46" data-toc-modified-id="Упражнение-46-1.47"><span class="toc-item-num">1.47&nbsp;&nbsp;</span>Упражнение 46</a></span></li><li><span><a href="#Упражнение-47" data-toc-modified-id="Упражнение-47-1.48"><span class="toc-item-num">1.48&nbsp;&nbsp;</span>Упражнение 47</a></span></li><li><span><a href="#Упражнение-48" data-toc-modified-id="Упражнение-48-1.49"><span class="toc-item-num">1.49&nbsp;&nbsp;</span>Упражнение 48</a></span></li><li><span><a href="#Упражнение-49" data-toc-modified-id="Упражнение-49-1.50"><span class="toc-item-num">1.50&nbsp;&nbsp;</span>Упражнение 49</a></span></li><li><span><a href="#Упражнение-50" data-toc-modified-id="Упражнение-50-1.51"><span class="toc-item-num">1.51&nbsp;&nbsp;</span>Упражнение 50</a></span></li><li><span><a href="#Упражнение-51" data-toc-modified-id="Упражнение-51-1.52"><span class="toc-item-num">1.52&nbsp;&nbsp;</span>Упражнение 51</a></span></li><li><span><a href="#Упражнение-52" data-toc-modified-id="Упражнение-52-1.53"><span class="toc-item-num">1.53&nbsp;&nbsp;</span>Упражнение 52</a></span></li><li><span><a href="#Упражнение-53" data-toc-modified-id="Упражнение-53-1.54"><span class="toc-item-num">1.54&nbsp;&nbsp;</span>Упражнение 53</a></span></li><li><span><a href="#Упражнение-54" data-toc-modified-id="Упражнение-54-1.55"><span class="toc-item-num">1.55&nbsp;&nbsp;</span>Упражнение 54</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Упражнения, чтобы проверить и улучшить свои знания по программированию на Python
# ## *Просьба скачать этот файл себе на компьютер и работать с ним там.*
# Ниже представлено 54 упражнения, представляющих собой код с пропущенными фрагментами, которые надо воспроизвести. Часть из этих упражнений очень простые, над некоторыми надо хорошенько подумать.
#
# Удачи в их выполнении!

# %% [markdown]
# ## Упражнение 1
# Допишите пропущенную часть кода, чтобы вывести на экран фразу "Hello world".

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Упражнение 2
# С помощью отступов исправьте программу, чтобы выводилось сообщение

# %%
if 5 > 2:
  print("Пять больше двух!")
# Out:
# Пять больше двух!

# %% [markdown]
# ## Упражнение 3
# Для записи комментариев в Python используется специальный символ. Превратите строку следующей ячейки в комментарий.

# %%
# Это комментарий, а не код

# %% [markdown]
# ## Упражнение 4
# Помимо однострочных комментариев в Python можно делать и многострочные. Превратите текст в ячейке ниже в многострочный комментарий.

# %%
'''Это комментарий, записанный
в более чем одну строку '''

# %% [markdown]
# ## Упражнение 5
# Создайте переменную myName и присвойте ей значение в виде своего имени.

# %%
myName = "Polina"

print(myName)
# Out:
# Polina

# %% [markdown]
# ## Упражнение 6
# Создайте переменную y и присвойте ей значение 1000.

# %%
y = 1000

print(y)
# Out:
# 1000

# %% [markdown]
# ## Упражнение 7
# Используя переменные x и y, выведите сумму чисел 50 и 60.

# %%
x = 50
y = 60

print(x + y)
# Out:
# 110

# %% [markdown]
# ## Упражнение 8
# Для нахождения суммы x и y создайте переменную z. Выведите результат сложения на экран.

# %%
x = 5
y = 10

z = y + x
print(z)
# Out:
# 15

# %% [markdown]
# ## Упражнение 9
# Уберите из имени переменной только те символы, которые нельзя использовать для создания переменных.

# %%
myfirst_name = "Василий"

# %% [markdown]
# ## Упражнение 10
# Используя функцию len, выведите на экран значение длины строки

# %%
x = "Hello World"
print(len(x))
# Out:
# 11

# %% [markdown]
# ## Упражнение 11
# Присвойте переменной x значение первого символа строки txt.

# %%
txt = "Hello World"
x = txt[0]

print(x)
# Out:
# H

# %% [markdown]
# ## Упражнение 12
# Присвойте переменной x значение строки из символов со второй по пятый из строки txt.

# %%
txt = "Hello World"
x = txt[1: 4: 1]

print(x)
# Out:
# ell

# %% [markdown]
# ## Упражнение 13
# Присвойте переменной x значение строки txt, только без пробелов в начале и конце.

# %%
txt = " Hello World "
x = txt.replace(" ", "")

print(x)
# Out:
# HelloWorld

# %% [markdown]
# ## Упражнение 14
# Преобразуйте строку txt в строку, состоящую только из заглавных букв.

# %%
txt = "Hello World"

print(txt.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# ## Упражнение 15
# Преобразуйте строку txt в строку, состоящую только из строчных букв.

# %%
txt = "Hello World"

print(txt.lower())
# Out:
# hello world

# %% [markdown]
# ## Упражнение 16
# Замените в строке символ __H__ на символ **J**.

# %%
txt = "Hello World Hi"

txt.replace("H", "J")
# Out:
# 'Jello World Ji'

# %% [markdown]
# ## Упражнение 17
# Перемножьте числа 110 и 53 и выведите результат.

# %%
print(110 * 53)
# Out:
# 5830

# %% [markdown]
# ## Упражнение 18
# Выведите на экран остаток от деления 57 и 13

# %%
print(57 % 13)
# Out:
# 5

# %% [markdown]
# ## Упражнение 19
# Используйте правильный оператор принадлежности, чтобы проверить, является ли яблоко элементом списка фруктов.

# %%
fruits = ["apple", "banana"]
if "apple" in fruits:
  print("Yes, apple is a fruit!")
# Out:
# Yes, apple is a fruit!

# %% [markdown]
# ## Упражнение 20
# Используйте оператор неравенства.

# %%
if 5!=10:
  print("5 and 10 is not equal")
# Out:
# 5 and 10 is not equal

# %% [markdown]
# ## Упражнение 21
# Используйте логический оператор, чтобы проверить наличие истинности хотя бы одного из двух условий.

# %%
if 5 == 10 or 4 == 4:
  print("Хотя бы одно из условий истинно")
# Out:
# Хотя бы одно из условий истинно

# %% [markdown]
# ## Упражнение 22
# Выведите на экран второй элемент списка.

# %%
fruits = ["apple", "banana", "cherry"]

print(fruits[1])
# Out:
# banana

# %% [markdown]
# ## Упражнение 23
# Замените в списке фруктов яблоко на киви.

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kivi"
print(fruits)
# Out:
# ['kivi', 'banana', 'cherry']

# %% [markdown]
# ## Упражнение 24
# Добавьте апельсин в спискок фруктов.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ## Упражнение 25
# Вставьте лимон вторым элементом списка фруктов.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print(fruits)
# Out:
# ['apple', 'lemon', 'banana', 'cherry']

# %% [markdown]
# ## Упражнение 26
# Удалите банан из списка фруктов.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ## Упражнение 27
# Выведите первый элемент кортежа.

# %%
fruits = ("apple", "banana", "cherry")
print(fruits[0])
# Out:
# apple

# %% [markdown]
# ## Упражнение 28
# Выведите на экран число элементов кортежа.

# %%
fruits = ("apple", "banana", "cherry")
print(len(fruits))
# Out:
# 3

# %% [markdown]
# ## Упражнение 29
# Проверьте, является ли яблоко элементом множества фруктов.

# %%
fruits = {"apple", "banana", "cherry"}
if( "apple" in fruits ):
  print("Yes, apple is a fruit!")
# Out:
# Yes, apple is a fruit!

# %% [markdown]
# ## Упражнение 30
# Добавьте апельсин ко множеству фруктов.

# %%
fruits = {"apple", "banana", "cherry"}
fruits.add("orange")

print(fruits)
# Out:
# {'banana', 'apple', 'orange', 'cherry'}

# %% [markdown]
# ## Упражнение 31
# Используйте метод для добавления сразу нескольких элементов из списка ко множеству фруктов.

# %%
fruits = {"apple", "banana", "cherry"}
fruits = fruits.union( {'grapes', 'mango', 'orange'} )
fruits
# Out:
# {'apple', 'banana', 'cherry', 'grapes', 'mango', 'orange'}

# %% [markdown]
# ## Упражнение 32
# Уберите банан из множества фруктов.

# %%
fruits = {"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# ## Упражнение 33
# Уберите первый элемент из множества фруктов.

# %%
fruits = {"apple", "banana", "cherry"}
if fruits:
    fruits.pop()
print(fruits)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# ## Упражнение 34
# Выведите на экран значение для ключа "model" словаря "car".

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(car.get("model"))
# Out:
# Mustang

# %% [markdown]
# ## Упражнение 35
# Замените в словаре значение года на 2019.

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car["year"] = 2019

car
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2019}

# %% [markdown]
# ## Упражнение 36
# Добавьте элемент в словарь с ключом "color" и значчением "red".

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car["color"] = "red"
car
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %% [markdown]
# ## Упражнение 37
# Удалите элемент модели из словаря.

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.pop("year")

car
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# ## Упражнение 38
# Очистите словарь.

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.clear()
car
# Out:
# {}

# %% [markdown]
# ## Упражнение 39
# Дополните текст программы таким образом, чтобы в случае если a больше чем b, выводилось сообщение.

# %%
a = 50
b = 10

if(a > b):
  print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Упражнение 40
# Если a не равно b, пусть выводится сообщение.

# %%
a = 50
b = 10

if(a!=b):
  print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Упражнение 41
# Пусть программа выводит ответ "Да", если a равно b, и "Нет" в противном случае.

# %%
a = 50
b = 10
if(a ==b ):
  print("Да")
else:
  print("Нет")
# Out:
# Нет

# %% [markdown]
# ## Упражнение 42
# Если a равно b,  пусть выводится единица, двойка, если a больше b, в противном случае выводится тройка.

# %%
a = 50
b = 10

if(a ==b ):
  print(1)
elif (a > b):
  print(2)
else:
  print(3)
# Out:
# 2

# %% [markdown]
# ## Упражнение 43
# Пусть программа выводит сообщение, если a равно b и c равно d.

# %%
a=20
b=20
c=35
d=35

if(a == b and c == d):
  print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Упражнение 44
# Пусть сообщение выводится в случае истинности хотя бы одного из условий.

# %%
a = 10
b = 10
c = 15
d = 22

if(a == b or c == d):
  print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Упражнение 45
# Пусть программа выводит i пока i меньше 6.

# %%
i = 1

while(i < 6):
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Упражнение 46
# Остановите выполнение цикла, если i равно трем.

# %%
i = 1
while i < 6:
  if i == 3:
    break


  i += 1

# %% [markdown]
# ## Упражнение 47
# Выполните цикл по элементам списка фруктов.

# %%
fruits = ["apple", "banana", "cherry"]

for i in fruits:
  print(i)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Упражнение 48
# Вывести на экран все элементы списка, кроме банана.

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    if(x != "banana"):
      print(x)
# Out:
# apple
# cherry

# %% [markdown]
# ## Упражнение 49
# С помощью функции range выполните цикл 6 раз.

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Упражнение 50
# Создайте свою функцию.

# %%
def f()  : print("Hello from a function")

# %% [markdown]
# ## Упражнение 51
# Запустите функцию, созданную в предыдущем упражнении.

# %%
print(f())
# Out:
# Hello from a function
# None

# %% [markdown]
# ## Упражнение 52
# Для функции с двумя параметрами сделайте, чтобы она выводила второ параметр на экран.

# %%
def f(x, y) :{
    print (y)
}

print(f(4, 5))
# Out:
# 5
# None

# %% [markdown]
# ## Упражнение 53
# Сделайте функцию, которая возводит число в степень, также равную этому числу.

# %%
def my_function(x):{
    print(pow(x, x))
}

print(my_function(4))
# Out:
# 256
# None

# %% [markdown]
# ## Упражнение 54
# Создайте анонимную функцию, которая получает один параметр и выводит его на экран.

# %%
res = lambda x: print(x)
print(res(5))
# Out:
# 5
# None
